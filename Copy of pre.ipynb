# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/data science/Car_sales.csv')
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
df.tail()
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 152                24.4          1.9       160.0      100.5   67.6   176.6
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
# ...

# %%
df.shape
# Out:
# (157, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=157, step=1)

# %%
df.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull())
plt.show()

# %%
df.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
df.drop(['Manufacturer','Model','Vehicle_type','Latest_Launch','Fuel_efficiency'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Sales_in_thousands  __year_resale_value  Price_in_thousands  Engine_size  \
# 0              16.919               16.360               21.50          1.8
# 1              39.384               19.875               28.40          3.2
# 2              14.114               18.225                 NaN          3.2
# 3               8.588               29.725               42.00          3.5
# 4              20.397               22.255               23.99          1.8
#
#    Horsepower  Wheelbase  Width  Length  Curb_weight  Fuel_capacity  \
# 0       140.0      101.2   67.3   172.4        2.639           13.2
# 1       225.0      108.1   70.3   192.9        3.517           17.2
# 2       225.0      106.9   70.6   192.0        3.470           17.2
# 3       210.0      114.6   71.4   196.6        3.850           18.0
# 4       150.0      102.6   68.2   178.0        2.998           16.4
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# ...

# %%
graph=df.select_dtypes(include=['float'])
graph.hist(figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
for i in ['__year_resale_value','Price_in_thousands','Engine_size',
          'Horsepower','Wheelbase','Width','Length','Curb_weight','Fuel_capacity',
          'Power_perf_factor']:
          df[i]=df[i].fillna(df[i].median())

# %%
df.isnull().sum()
# Out:
# Sales_in_thousands     0
# __year_resale_value    0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Power_perf_factor      0
# dtype: int64

# %%
sns.rugplot(df['Sales_in_thousands'])
plt.title('RUGPLOT OF SALES OF CAR')

plt.show()

# %%
sns.barplot(x='Sales_in_thousands',data=df)
plt.show()

# %%
sns.relplot(x='Sales_in_thousands',y='Price_in_thousands',data=df)
plt.title('relplot')
plt.show()

# %%
sns.relplot(x='Sales_in_thousands',y='Price_in_thousands',data=df,hue='Fuel_capacity')
plt.title('relplot')
plt.show()

# %%
plt.boxplot(df['Sales_in_thousands'])
plt.title('BOXPLOT OF Sales_in_thousands')
plt.show()

# %%
q1=np.percentile(df['Sales_in_thousands'],25,interpolation='midpoint')
q2=np.percentile(df['Sales_in_thousands'],50,interpolation='midpoint')
q3=np.percentile(df['Sales_in_thousands'],75,interpolation='midpoint')
print(q1)
print(q2)
print(q3)
# Out:
# 14.114
# 29.45
# 67.956
# <ipython-input-164-7755892f0bd4>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['Sales_in_thousands'],25,interpolation='midpoint')
# <ipython-input-164-7755892f0bd4>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['Sales_in_thousands'],50,interpolation='midpoint')
# <ipython-input-164-7755892f0bd4>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
df['Sales_in_thousands'].median()
# Out:
# 29.45

# %%
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(lower)
print(upper)
# Out:
# -66.649
# 148.719

# %%
outlier=[]
for x in df['Sales_in_thousands']:
  if ((x>upper) or (x<lower)):
    outlier.append(x)
outlier
# Out:
# [227.061,
#  181.749,
#  245.815,
#  175.67,
#  276.747,
#  155.787,
#  220.65,
#  540.561,
#  199.685,
#  230.902,
#  157.04,
#  247.994]

# %%
ind=df['Sales_in_thousands']>upper
df.loc[ind].index
# Out:
# Int64Index([40, 45, 49, 50, 52, 53, 55, 56, 57, 58, 69, 137], dtype='int64')

# %%
df.drop([40, 45, 49, 50, 52, 53, 55, 56, 57, 58, 69, 137],inplace=True)

# %%
plt.boxplot(df['Sales_in_thousands'])
plt.title('OUTLIER REMOVED BOXPLOT')
plt.show()

# %%
plt.boxplot(df['__year_resale_value'])
plt.title('BOXPLOT OF __year_resale_value')
plt.show()

# %%
q1=np.percentile(df['__year_resale_value'],25,interpolation='midpoint')
q2=np.percentile(df['__year_resale_value'],50,interpolation='midpoint')
q3=np.percentile(df['__year_resale_value'],75,interpolation='midpoint')
print(q1)
print(q2)
print(q3)
# Out:
# 12.64
# 14.18
# 18.225
# <ipython-input-172-850fa57663f4>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['__year_resale_value'],25,interpolation='midpoint')
# <ipython-input-172-850fa57663f4>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['__year_resale_value'],50,interpolation='midpoint')
# <ipython-input-172-850fa57663f4>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(lower)
print(upper)
# Out:
# 4.262499999999999
# 26.602500000000003

# %%
outlier=[]
for x in df['Sales_in_thousands']:
  if ((x>upper) or (x<lower)):
    outlier.append(x)
outlier
# Out:
# [39.384,
#  1.38,
#  91.561,
#  39.35,
#  27.851,
#  83.257,
#  63.729,
#  145.519,
#  135.126,
#  42.593,
#  32.299,
#  107.995,
#  32.775,
#  31.148,
#  32.306,
#  53.48,
#  30.696,
#  76.034,
#  71.186,
#  88.028,
#  0.916,
#  31.038,
#  111.313,
#  101.323,
#  70.227,
#  113.369,
#  35.068,
#  63.403,
#  125.338,
#  73.203,
#  76.029,
#  41.184,
#  66.692,
#  29.45,
#  55.557,
#  80.556,
#  3.334,
#  51.238,
#  48.911,
#  42.541,
#  55.616,
#  0.11,
#  39.348,
#  67.956,
#  81.174,
#  27.609,
#  27.602,
#  3.311,
#  1.526,
#  0.954,
#  28.976,
#  42.643,
#  88.094,
#  79.853,
#  27.308,
#  42.574,
#  54.158,
#  65.005,
#  1.112,
#  38.554,
#  80.255,
#  32.734,
#  1.872,
#  51.645,
#  131.097,
#  92.364,
#  35.945,
#  39.572,
#  1.28,
#  1.866,
#  80.62,
#  49.989,
#  47.107,
#  33.028,
#  142.535,
#  63.849,
#  33.269,
#  84.087,
#  65.119,
#  68.411,
#  83.721,
#  51.102,
#  49.463,
#  3.545,
#  3.493]

# %%
ind=df['Sales_in_thousands']>upper
df.loc[ind].index
# Out:
# Int64Index([  1,  10,  11,  12,  13,  14,  19,  20,  22,  25,  27,  29,  30,
#              31,  33,  34,  35,  37,  38,  42,  43,  44,  46,  47,  48,  51,
#              54,  59,  61,  62,  63,  64,  67,  68,  75,  77,  80,  81,  85,
#              88,  89,  90,  93, 100, 101, 102, 103, 104, 105, 106, 107, 109,
#             110, 114, 118, 119, 121, 122, 123, 129, 133, 134, 135, 136, 138,
#             139, 140, 141, 143, 146, 147, 150],
#            dtype='int64')

# %%
df.drop([1,  10,  11,  12,  13,  14,  19,  20,  22,  25,  27,  29,  30,
             31,  33,  34,  35,  37,  38,  42,  43,  44,  46,  47,  48,  51,
             54,  59,  61,  62,  63,  64,  67,  68,  75,  77,  80,  81,  85,
             88,  89,  90,  93, 100, 101, 102, 103, 104, 105, 106, 107, 109,
            110, 114, 118, 119, 121, 122, 123, 129, 133, 134, 135, 136, 138,
            139, 140, 141, 143, 146, 147, 150],inplace=True)

# %%
plt.boxplot(df['Sales_in_thousands'])
plt.title('OUTLIER REMOVED')
plt.show()

# %%
plt.boxplot(df['Price_in_thousands'])
plt.title('BOXPLOT OF Price_in_thousands')
plt.show()

# %%
q1=np.percentile(df['__year_resale_value'],25,interpolation='midpoint')
q2=np.percentile(df['__year_resale_value'],50,interpolation='midpoint')
q3=np.percentile(df['__year_resale_value'],75,interpolation='midpoint')
print(q1)
print(q2)
print(q3)
# Out:
# 14.18
# 14.795
# 23.555
# <ipython-input-179-850fa57663f4>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['__year_resale_value'],25,interpolation='midpoint')
# <ipython-input-179-850fa57663f4>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['__year_resale_value'],50,interpolation='midpoint')
# <ipython-input-179-850fa57663f4>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(lower)
print(upper)
# Out:
# 0.11749999999999972
# 37.6175

# %%
outlier=[]
for x in df['__year_resale_value']:
  if ((x>upper) or (x<lower)):
    outlier.append(x)
outlier
# Out:
# [39.0, 58.47, 40.375, 50.375, 58.6, 41.25, 60.625, 67.55]

# %%
ind=df['__year_resale_value']>upper
df.loc[ind].index
# Out:
# Int64Index([6, 39, 73, 94, 95, 124, 125, 126], dtype='int64')

# %%
df.drop([6, 39, 73, 94, 95, 124, 125, 126],inplace=True)

# %%
plt.boxplot(df['__year_resale_value'])
plt.title('OUTLIER REMOVED')
plt.show()

# %%
plt.boxplot(df['Engine_size'])
plt.title('BOXPLOT OF Engine_size')
plt.show()

# %%
q1=np.percentile(df['Engine_size'],25,interpolation='midpoint')
q2=np.percentile(df['Engine_size'],50,interpolation='midpoint')
q3=np.percentile(df['Engine_size'],75,interpolation='midpoint')
print(q1)
print(q2)
print(q3)
# Out:
# 2.2
# 3.0
# 3.5
# <ipython-input-186-67501bb6b137>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['Engine_size'],25,interpolation='midpoint')
# <ipython-input-186-67501bb6b137>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['Engine_size'],50,interpolation='midpoint')
# <ipython-input-186-67501bb6b137>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(lower)
print(upper)
# Out:
# 0.25000000000000044
# 5.449999999999999

# %%
outlier=[]
for x in df['Engine_size']:
  if ((x>upper) or (x<lower)):
    outlier.append(x)
outlier
# Out:
# [5.7, 5.7]

# %%
ind=df['Engine_size']>upper
df.loc[ind].index
# Out:
# Int64Index([18, 24], dtype='int64')

# %%
df.drop([18, 24],inplace=True)

# %%
plt.boxplot(df['Engine_size'])
plt.title('outlier removed')
plt.show()

# %%
plt.boxplot(df['Horsepower'])
plt.title('boxplot of horsepower')
plt.show()

# %%
q1=np.percentile(df['Horsepower'],25,interpolation='midpoint')
q2=np.percentile(df['Horsepower'],50,interpolation='midpoint')
q3=np.percentile(df['Horsepower'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 155.0
# 185.0
# 220.0
# <ipython-input-193-9687bf35b3e0>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['Horsepower'],25,interpolation='midpoint')
# <ipython-input-193-9687bf35b3e0>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['Horsepower'],50,interpolation='midpoint')
# <ipython-input-193-9687bf35b3e0>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(lower)
print(upper)
# Out:
# 57.5
# 317.5

# %%
outlier=[]
for i in df['Horsepower']:
  if((i>upper) or (i<lower)):
    outlier.append(i)
outlier
# Out:
# [55.0]

# %%
ind3=df['Horsepower']<lower
df.loc[ind3].index
# Out:
# Int64Index([26], dtype='int64')

# %%
df.drop([26],inplace=True)

# %%
plt.boxplot(df['Horsepower'])
plt.title('outlier removed boxplot')
plt.show()

# %%
plt.boxplot(df['Wheelbase'])
plt.title('boxplot of Wheelbase')
plt.show()

# %%
plt.boxplot(df['Width'])
plt.title('box plot of Width')
plt.show()

# %%
plt.boxplot(df['Length'])
plt.title('boxplot of Length')
plt.show()

# %%
plt.boxplot(df['Curb_weight'])
plt.title('boxplot od Curb_weight')
plt.show()

# %%
q1=np.percentile(df['Curb_weight'],25,interpolation='midpoint')
q2=np.percentile(df['Curb_weight'],50,interpolation='midpoint')
q3=np.percentile(df['Curb_weight'],75,interpolation='midpoint')

print(q1)
print(q2)
print(q3)
# Out:
# 2.998
# 3.3360000000000003
# 3.6715
# <ipython-input-203-1a14bd3f16e5>:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q1=np.percentile(df['Curb_weight'],25,interpolation='midpoint')
# <ipython-input-203-1a14bd3f16e5>:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   q2=np.percentile(df['Curb_weight'],50,interpolation='midpoint')
# <ipython-input-203-1a14bd3f16e5>:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# ...

# %%
iqr=q3-q1
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(lower)
print(upper)
# Out:
# 1.9877500000000006
# 4.681749999999999

# %%
out=[]
for x in df['Curb_weight']:
  if((x>upper) or (x<lower)):
    out.append(x)
out
# Out:
# [5.401, 5.393, 5.115]

# %%
ind4=df['Curb_weight']<upper
df.loc[ind4].index
# Out:
# Int64Index([  0,   2,   3,   4,   5,   7,   8,   9,  15,  16,  17,  21,  23,
#              28,  32,  36,  41,  60,  65,  66,  70,  71,  72,  76,  79,  82,
#              83,  84,  86,  87,  91,  92,  96,  97,  98,  99, 108, 111, 112,
#             113, 115, 116, 117, 120, 127, 128, 130, 131, 132, 142, 145, 148,
#             149, 151, 152, 153, 154, 155, 156],
#            dtype='int64')

# %%
df.drop([0,   2,   3,   4,   5,   7,   8,   9,  15,  16,  17,  21,  23,
             28,  32,  36,  41,  60,  65,  66,  70,  71,  72,  76,  79,  82,
             83,  84,  86,  87,  91,  92,  96,  97,  98,  99, 108, 111, 112,
            113, 115, 116, 117, 120, 127, 128, 130, 131, 132, 142, 145, 148,
            149, 151, 152, 153, 154, 155, 156],inplace=True)

# %%
plt.boxplot(df['Curb_weight'])
plt.title('outlier removed')
plt.show()

# %%
plt.boxplot(df['Fuel_capacity'])
plt.title('boxplt of Fuel_capacity')
plt.show()

# %%
plt.boxplot(df['Power_perf_factor'])
plt.title('boxplot of Power_perf_factor')
plt.show()

# %%
df.columns
# Out:
# Index(['Sales_in_thousands', '__year_resale_value', 'Price_in_thousands',
#        'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length',
#        'Curb_weight', 'Fuel_capacity', 'Power_perf_factor'],
#       dtype='object')

# %%
core=df.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(core,vmin=0.4,vmax=0.9,annot=True,linewidth=0.2)
plt.show()

# %%
y=df['Sales_in_thousands']
x=df.drop('Sales_in_thousands',axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn import linear_model
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
prediction=model.predict(x_test)
prediction
# Out:
# array([8.55223199])

# %%
from sklearn.metrics import mean_squared_error


print('mSE:',mean_squared_error(y_test,prediction))
# Out:
# mSE: 0.32920973397616676

# %%
from sklearn.metrics import r2_score
print('R squared values is :',r2_score(y_test,prediction))
# Out:
# R squared values is : nan
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
x.describe()
# Out:
#               0             1         2             3             4  \
# count  3.000000  3.000000e+00  3.000000  3.000000e+00  3.000000e+00
# mean   0.000000 -3.469447e-16  0.000000 -2.960595e-16  4.440892e-15
# std    1.224745  1.224745e+00  1.224745  1.224745e+00  1.224745e+00
# min   -0.707107 -1.240591e+00 -0.707107 -7.071068e-01 -7.071068e-01
# 25%   -0.707107 -6.041291e-01 -0.707107 -7.071068e-01 -7.071068e-01
# 50%   -0.707107  3.233314e-02 -0.707107 -7.071068e-01 -7.071068e-01
# 75%    0.353553  6.202957e-01  0.353553  3.535534e-01  3.535534e-01
# max    1.414214  1.208258e+00  1.414214  1.414214e+00  1.414214e+00
#
#                   5             6         7             8             9
# count  3.000000e+00  3.000000e+00  3.000000  3.000000e+00  3.000000e+00
# mean  -2.886580e-15  1.628327e-15  0.000000 -5.181041e-16 -5.181041e-16
# std    1.224745e+00  1.224745e+00  1.224745  1.224745e+00  1.224745e+00
# ...

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn import preprocessing
standerds=preprocessing.StandardScaler()
x=standerds.fit_transform(x)

# %%
#x.describe()

# %%
x=pd.DataFrame(x)
x.describe()
# Out:
#               0             1         2             3             4  \
# count  3.000000  3.000000e+00  3.000000  3.000000e+00  3.000000e+00
# mean   0.000000 -3.469447e-16  0.000000 -2.960595e-16  4.440892e-15
# std    1.224745  1.224745e+00  1.224745  1.224745e+00  1.224745e+00
# min   -0.707107 -1.240591e+00 -0.707107 -7.071068e-01 -7.071068e-01
# 25%   -0.707107 -6.041291e-01 -0.707107 -7.071068e-01 -7.071068e-01
# 50%   -0.707107  3.233314e-02 -0.707107 -7.071068e-01 -7.071068e-01
# 75%    0.353553  6.202957e-01  0.353553  3.535534e-01  3.535534e-01
# max    1.414214  1.208258e+00  1.414214  1.414214e+00  1.414214e+00
#
#                   5             6         7             8             9
# count  3.000000e+00  3.000000e+00  3.000000  3.000000e+00  3.000000e+00
# mean  -2.886580e-15  1.628327e-15  0.000000 -5.181041e-16 -5.181041e-16
# std    1.224745e+00  1.224745e+00  1.224745  1.224745e+00  1.224745e+00
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)
lr=linear_model.LinearRegression()
model=lr.fit(x_train,y_train)
print('R squared values is :',r2_score(y_test,prediction))
print('mSE:',mean_squared_error(y_test,prediction))
# Out:
# R squared values is : nan
# mSE: 0.32920973397616676
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_regression.py:918: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
